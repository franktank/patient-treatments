# %%
import pandas as pd

diagnosis = pd.read_csv('./Patient_Diagnosis.csv')
treatment = pd.read_csv('./Patient_Treatment.csv')
icd9cm_code = pd.read_excel('./CMS32_DESC_LONG_SHORT_DX.xlsx')
icd9cm_code.columns = ['Diagnosis_Code', 'Long_Description', 'Short_Description']
diagnosis['Diagnosis_Code'] *= 10
diagnosis['Diagnosis_Code'] = diagnosis['Diagnosis_Code'].astype(str).str.replace('.0', '')
treatment_diagnosis_df = pd.merge(treatment, diagnosis,  how='inner', left_on=['Patient_ID'], right_on = ['Patient_ID'])
tdc = pd.merge(treatment_diagnosis_df, icd9cm_code, how='inner', left_on=['Diagnosis_Code'], right_on=['Diagnosis_Code'])

# %%
# Diseases treated at the clinic
"""
Drop duplicates to find unique diseases treated at the clinic
"""
diseases = tdc.drop_duplicates(subset=['Diagnosis_Code','Diagnosis','Long_Description','Short_Description'])
diseases[['Diagnosis_Code','Diagnosis','Long_Description']]
# Out:
#      Diagnosis_Code      Diagnosis  \
# 0              1749  Breast Cancer
# 238            1741  Breast Cancer
# 328            1539   Colon Cancer
# 378            1533   Colon Cancer
# 453            1535   Colon Cancer
# 548            1534   Colon Cancer
# 626            1745  Breast Cancer
# 671            1748  Breast Cancer
# 805            1746  Breast Cancer
# 846            1743  Breast Cancer
# 924            1744  Breast Cancer
# 980            1742  Breast Cancer
# 1049           1537   Colon Cancer
# 1059           1536   Colon Cancer
# 1072           1538   Colon Cancer
#
#                                        Long_Description
# 0     Malignant neoplasm of breast (female), unspeci...
# 238   Malignant neoplasm of central portion of femal...
# 328       Malignant neoplasm of colon, unspecified site
# 378                 Malignant neoplasm of sigmoid colon
# 453          Malignant neoplasm of appendix vermiformis
# 548                         Malignant neoplasm of cecum
# 626   Malignant neoplasm of lower-outer quadrant of ...
# 671   Malignant neoplasm of other specified sites of...
# 805   Malignant neoplasm of axillary tail of female ...
# 846   Malignant neoplasm of lower-inner quadrant of ...
# 924   Malignant neoplasm of upper-outer quadrant of ...
# 980   Malignant neoplasm of upper-inner quadrant of ...
# 1049              Malignant neoplasm of splenic flexure
# 1059              Malignant neoplasm of ascending colon
# 1072  Malignant neoplasm of other specified sites of...

# %%
# How many patients does the clinic have for each cancer type?
"""
Group by diagnosis code, and find counts for each cancer type by being unique on Patient_ID
"""
code_counts = tdc.groupby('Diagnosis_Code')
code_counts = code_counts['Patient_ID'].nunique().to_frame("Patient_Counts").reset_index()
cancer_type_counts = pd.merge(code_counts, icd9cm_code, how='inner', left_on=['Diagnosis_Code'], right_on=['Diagnosis_Code'])
cancer_type_counts
# Out:
#    Diagnosis_Code  Patient_Counts  \
# 0            1533               2
# 1            1534               4
# 2            1535               3
# 3            1536               1
# 4            1537               1
# 5            1538               1
# 6            1539               2
# 7            1741               4
# 8            1742               1
# 9            1743               3
# 10           1744               1
# 11           1745               3
# 12           1746               1
# 13           1748               5
# 14           1749              12
#
#                                      Long_Description  \
# 0                 Malignant neoplasm of sigmoid colon
# 1                         Malignant neoplasm of cecum
# 2          Malignant neoplasm of appendix vermiformis
# 3               Malignant neoplasm of ascending colon
# 4               Malignant neoplasm of splenic flexure
# 5   Malignant neoplasm of other specified sites of...
# 6       Malignant neoplasm of colon, unspecified site
# 7   Malignant neoplasm of central portion of femal...
# 8   Malignant neoplasm of upper-inner quadrant of ...
# 9   Malignant neoplasm of lower-inner quadrant of ...
# 10  Malignant neoplasm of upper-outer quadrant of ...
# 11  Malignant neoplasm of lower-outer quadrant of ...
# 12  Malignant neoplasm of axillary tail of female ...
# 13  Malignant neoplasm of other specified sites of...
# 14  Malignant neoplasm of breast (female), unspeci...
#
#            Short_Description
# 0      Mal neo sigmoid colon
# 1   Malignant neoplasm cecum
# 2     Malignant neo appendix
# 3     Malig neo ascend colon
# 4    Mal neo splenic flexure
# 5    Malignant neo colon NEC
# 6    Malignant neo colon NOS
# 7     Mal neo breast-central
# 8    Mal neo breast up-inner
# 9   Mal neo breast low-inner
# 10   Mal neo breast up-outer
# 11  Mal neo breast low-outer
# 12   Mal neo breast-axillary
# 13   Malign neopl breast NEC
# 14   Malign neopl breast NOS

# %%
# How long after being diagnosed do patients start treatment?
"""
Sort by treatment dates, and find the earliest one for each patient and diagnosis date.
Convert the date columns into datetime type.
Subtract Treatment_Date column with Diagnosis_Date column.
Store in a column.
"""
time = tdc.sort_values('Treatment_Date').groupby(['Patient_ID','Diagnosis_Date'], as_index=False).first()
time['Diagnosis_Date'] = pd.to_datetime(time['Diagnosis_Date'])
time['Treatment_Date'] = pd.to_datetime(time['Treatment_Date'])
time['Days_Until_Treatment'] = time['Treatment_Date'] - time['Diagnosis_Date']
time
# Out:
#     Patient_ID Diagnosis_Date Treatment_Date Drug_Code Diagnosis_Code  \
# 0         2038     2010-01-21     2010-01-24         A           1749
# 1         2120     2010-01-09     2010-01-24         A           1741
# 2         2407     2010-06-13     2010-06-19         A           1749
# 3         2425     2010-12-15     2011-01-12         B           1749
# 4         2462     2011-01-07     2011-01-11         A           1749
# 5         2634     2011-02-19     2011-02-23         B           1539
# 6         2735     2011-04-18     2011-04-23         B           1749
# 7         2763     2011-04-19     2011-04-23         A           1741
# 8         2770     2011-04-16     2011-04-22         B           1539
# 9         3095     2011-07-10     2011-07-13         A           1533
# 10        3449     2011-09-09     2011-10-11         C           1535
# 11        3757     2011-10-11     2012-01-10         C           1741
# 12        3757     2011-10-17     2012-01-10         C           1535
# 13        3948     2011-12-18     2012-01-11         A           1746
# 14        4256     2011-11-07     2012-01-01         C           1745
# 15        4354     2012-02-04     2012-02-14         C           1748
# 16        4374     2012-03-20     2012-03-25         C           1745
# 17        4692     2012-04-27     2012-04-30         B           1748
# 18        5259     2012-05-13     2012-10-12         C           1743
# 19        5657     2012-06-07     2012-10-14         C           1748
# 20        6281     2012-08-12     2013-01-12         C           1744
# 21        6321     2012-09-06     2013-01-13         C           1742
# 22        6837     2012-10-20     2013-01-13         B           1533
# 23        6840     2012-11-15     2013-01-14         B           1534
# 24        6877     2012-11-26     2013-01-14         C           1534
# 25        6877     2012-12-09     2013-01-14         C           1743
# 26        6889     2012-11-14     2013-01-01         C           1537
# 27        6922     2012-11-15     2013-01-10         C           1536
# 28        6922     2012-11-20     2013-01-10         C           1749
# 29        7230     2013-01-02     2013-01-16         C           1538
# 30        7230     2013-01-06     2013-01-16         C           1749
# 31        7242     2013-01-17     2014-01-18         C           1535
# 32        7796     2013-01-16     2013-01-21         A           1749
# 33        7937     2013-01-06     2013-01-12         A           1749
# 34        7976     2013-03-06     2013-03-11         A           1741
# 35        8480     2013-05-16     2013-05-22         A           1743
# 36        8827     2013-07-21     2013-10-14         A           1749
# 37        9331     2013-08-23     2014-01-10         C           1749
# 38        9489     2013-08-19     2013-10-11         C           1749
#
#         Diagnosis                                   Long_Description  \
# 0   Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 1   Breast Cancer  Malignant neoplasm of central portion of femal...
# 2   Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 3   Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 4   Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 5    Colon Cancer      Malignant neoplasm of colon, unspecified site
# 6   Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 7   Breast Cancer  Malignant neoplasm of central portion of femal...
# 8    Colon Cancer      Malignant neoplasm of colon, unspecified site
# 9    Colon Cancer                Malignant neoplasm of sigmoid colon
# 10   Colon Cancer         Malignant neoplasm of appendix vermiformis
# 11  Breast Cancer  Malignant neoplasm of central portion of femal...
# 12   Colon Cancer         Malignant neoplasm of appendix vermiformis
# 13  Breast Cancer  Malignant neoplasm of axillary tail of female ...
# 14  Breast Cancer  Malignant neoplasm of lower-outer quadrant of ...
# 15  Breast Cancer  Malignant neoplasm of other specified sites of...
# 16  Breast Cancer  Malignant neoplasm of lower-outer quadrant of ...
# 17  Breast Cancer  Malignant neoplasm of other specified sites of...
# 18  Breast Cancer  Malignant neoplasm of lower-inner quadrant of ...
# 19  Breast Cancer  Malignant neoplasm of other specified sites of...
# 20  Breast Cancer  Malignant neoplasm of upper-outer quadrant of ...
# 21  Breast Cancer  Malignant neoplasm of upper-inner quadrant of ...
# 22   Colon Cancer                Malignant neoplasm of sigmoid colon
# 23   Colon Cancer                        Malignant neoplasm of cecum
# 24   Colon Cancer                        Malignant neoplasm of cecum
# 25  Breast Cancer  Malignant neoplasm of lower-inner quadrant of ...
# 26   Colon Cancer              Malignant neoplasm of splenic flexure
# 27   Colon Cancer              Malignant neoplasm of ascending colon
# 28  Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 29   Colon Cancer  Malignant neoplasm of other specified sites of...
# 30  Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 31   Colon Cancer         Malignant neoplasm of appendix vermiformis
# 32  Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 33  Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 34  Breast Cancer  Malignant neoplasm of central portion of femal...
# 35  Breast Cancer  Malignant neoplasm of lower-inner quadrant of ...
# 36  Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 37  Breast Cancer  Malignant neoplasm of breast (female), unspeci...
# 38  Breast Cancer  Malignant neoplasm of breast (female), unspeci...
#
#            Short_Description     Days
# 0    Malign neopl breast NOS   3 days
# 1     Mal neo breast-central  15 days
# 2    Malign neopl breast NOS   6 days
# 3    Malign neopl breast NOS  28 days
# 4    Malign neopl breast NOS   4 days
# 5    Malignant neo colon NOS   4 days
# 6    Malign neopl breast NOS   5 days
# 7     Mal neo breast-central   4 days
# 8    Malignant neo colon NOS   6 days
# 9      Mal neo sigmoid colon   3 days
# 10    Malignant neo appendix  32 days
# 11    Mal neo breast-central  91 days
# 12    Malignant neo appendix  85 days
# 13   Mal neo breast-axillary  24 days
# 14  Mal neo breast low-outer  55 days
# 15   Malign neopl breast NEC  10 days
# 16  Mal neo breast low-outer   5 days
# 17   Malign neopl breast NEC   3 days
# 18  Mal neo breast low-inner 152 days
# 19   Malign neopl breast NEC 129 days
# 20   Mal neo breast up-outer 153 days
# 21   Mal neo breast up-inner 129 days
# 22     Mal neo sigmoid colon  85 days
# 23  Malignant neoplasm cecum  60 days
# 24  Malignant neoplasm cecum  49 days
# 25  Mal neo breast low-inner  36 days
# 26   Mal neo splenic flexure  48 days
# 27    Malig neo ascend colon  56 days
# 28   Malign neopl breast NOS  51 days
# 29   Malignant neo colon NEC  14 days
# 30   Malign neopl breast NOS  10 days
# 31    Malignant neo appendix 366 days
# 32   Malign neopl breast NOS   5 days
# 33   Malign neopl breast NOS   6 days
# 34    Mal neo breast-central   5 days
# 35  Mal neo breast low-inner   6 days
# 36   Malign neopl breast NOS  85 days
# 37   Malign neopl breast NOS 140 days
# 38   Malign neopl breast NOS  53 days

# %%
# Which treatment plan [drug(s)] do you think would be indicated to be used as first line of treatment for breast cancer?
"""
Initial approach was to look at number of treatments with each drug,
and duration of treatment with each drug.
Then, I noticed that some patients start off on a drug and then end up using another drug.
To find best first line of treatment, I need to fine drug that people start with and stop after finishing treatment.
"""
# Treatment counts with each drug
bc = tdc[tdc.Diagnosis == 'Breast Cancer']
breast_cancer = bc.groupby('Drug_Code')
breast_cancer = breast_cancer['Patient_ID'].nunique().to_frame('Treatment_Count').reset_index()
print(breast_cancer)

# Drug treatment duration for breast cancer
treatment_duration = bc.sort_values('Treatment_Date').groupby(['Patient_ID','Diagnosis_Date'], as_index=False).last()
treatment_duration['Diagnosis_Date'] = pd.to_datetime(treatment_duration['Diagnosis_Date'])
treatment_duration['Treatment_Date'] = pd.to_datetime(treatment_duration['Treatment_Date'])
treatment_duration['Treatment_Duration'] = (treatment_duration['Treatment_Date'] - treatment_duration['Diagnosis_Date']).dt.days
mean_treatment_duration = treatment_duration.groupby('Drug_Code', as_index=False)['Treatment_Duration'].mean() # Average duration of treatment in days
print(mean_treatment_duration)
# Find combinations of drug code and patients
drug_patient_combinations = bc.groupby(['Patient_ID', 'Drug_Code']).size().reset_index()
print(drug_patient_combinations)
# Out:
#   Drug_Code  Treatment_Count
# 0         A               19
# 1         B               13
# 2         C               15
#   Drug_Code  Treatment_Duration
# 0         A                  50
# 1         B                 550
# 2         C                  81
#     Patient_ID Drug_Code   0
# 0         2038         A   8
# 1         2038         B   8
# 2         2120         A  13
# 3         2120         B  13
# 4         2407         A   9
# 5         2407         B   9
# 6         2425         A  17
# 7         2425         B  17
# 8         2462         A  18
# 9         2462         B  18
# 10        2735         A  12
# 11        2735         B  12
# 12        2763         A  15
# 13        2763         B  15
# 14        3757         C  18
# 15        3948         A  16
# 16        3948         B  16
# 17        3948         C   9
# 18        4256         C  30
# 19        4354         C  30
# 20        4374         C  30
# 21        4692         A  15
# 22        4692         B  15
# 23        4692         C  20
# 24        5259         A  16
# 25        5259         B  16
# 26        5259         C  21
# 27        5657         A  13
# 28        5657         B  13
# 29        5657         C  13
# 30        6281         A  18
# 31        6281         B  18
# 32        6281         C  20
# 33        6321         A  24
# 34        6321         B  24
# 35        6321         C  21
# 36        6877         C  11
# 37        6922         C  13
# 38        7230         C  13
# 39        7796         A  14
# 40        7937         A  13
# 41        7976         A  16
# 42        8480         A  14
# 43        8827         A  18
# 44        9331         A  17
# 45        9331         C  13
# 46        9489         C   9

# %%
"""
In my opinion, the best first line of treatment would be Drug C by itself.
There is a general trend of treatment plans ending with C. 
Patients who start with Drug C, end with Drug C.
Patients who start with other treatments typically end with Drug C.

The other notable treatment plan is to start with Drug A, 
and then continue to Drug B, and then to Drug C if there is no success.

Also looking at the duration of usage with each drugs, it is notable that the
average duration for Drug B is extensively larger than that of Drug A and C.
This is not preferable if Drug B is chemotherapy, due to severe unwanted side effects.
However, if Drug B is immunotherapy, it is less taxing than chemotherapy on the body,
and could potentially be why there is a longer use of it.

Perhaps, Drug A is an anti-cancer drug that demonstrates the least amount of side effects,
which is why doctors prefer to start on Drug A. Then if Drug A doesn't work, they proceed to Drug B,
which is also minimally invasive on standard of life. If Drug B doesn't work, 
doctors will turn to a more intense drug, Drug C, in hopes of finally defeating the cancer.
"""

# %%
# How do these drugs compare in terms of duration of therapy?
"""
Take approach similar to finding days from diagnosis to treatment, however now we're looking for last date
of treatment.
"""
treatment_duration = tdc.sort_values('Treatment_Date').groupby(['Patient_ID','Diagnosis_Date'], as_index=False).last()
treatment_duration['Diagnosis_Date'] = pd.to_datetime(treatment_duration['Diagnosis_Date'])
treatment_duration['Treatment_Date'] = pd.to_datetime(treatment_duration['Treatment_Date'])
treatment_duration['Treatment_Duration'] = (treatment_duration['Treatment_Date'] - treatment_duration['Diagnosis_Date']).dt.days
treatment_duration.groupby('Drug_Code', as_index=False)['Treatment_Duration'].mean() # Average duration of treatment in days
# Out:
#   Drug_Code  Treatment_Duration
# 0         A           50.400000
# 1         B          363.500000
# 2         C           95.238095
